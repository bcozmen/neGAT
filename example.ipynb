# %%
from negat import PhysicsEngine


model = PhysicsEngine(num_agents=256)
model.train(50000)

model.plot_graph()
# Out:
# Training Simulation: 100%|█████████████████████████████████████████████████████████████████████████████████| 50000/50000 [04:49<00:00, 172.83it/s]

# %%
model.train(100000)

model.plot_graph()
# Out:
# Training Simulation: 100%|███████████████████████████████████████████████████████████████████████████████| 100000/100000 [09:55<00:00, 167.95it/s]

# %%
model.train(10000)

model.plot_graph()
# Out:
# Training Simulation: 100%|█████████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:01<00:00, 162.29it/s]
